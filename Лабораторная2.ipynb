# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiaTolstosheeva/MathModel/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Лабораторная работа №2**
#
# **Наргила Джепбарова**

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

data={ 1893:740,
      1894:1096,
      1897:8000,
      1903:27700,
      1912:63500,
      1917:69800,
      1921:67200,
      1926:120100,
      1931:180100,
      1939:404000,
      1945:606000,
      1959:885000,
      1963:990000,
      1964:1013000,
      1976:1285700,
      1979:1312400,
      1984:1436400,
      1989:1436400,
      1991:2744809,
      1992:2749253,
      1993:2746874,
      1994:2733738,
      1995:2732352,
      1996:2732721,
      1997:2729750,
      1998:2732245,
      1999:2734031,
      2000:2725499,
      2001:2715128,
      2002:2703012,
      2003:2688423,
      2004:2674155,
      2005:2665984,
      2006:2654853,
      2007:2647195,
      2008:2642727,
      2009:2648923,
      2010:2661594,
      2011:2666465,
      2012:2686863,
      2013:2709461,
      2014:2731176,
      2015:2746822,
      2016:2762237,
      2017:2779555,
      2018:2788849,
      2019:2793384,
      2020:2625631
      }
years=data.keys()
people=data.values()
years=np.array(list(years))
people=np.array(list(people))

def dydt(y, t):
    k=0.0525
    return k*y
solve=odeint(dydt,y0=740,t=years)
solve=solve.flatten()
# %matplotlib inline
plt.plot(years, solve, label = r"Жесткая модель Мальтуса", color="red")
plt.plot(years, people, label = r"Население Новосибирска", color="green")
plt.grid(True)
plt.legend()
plt.show()

# %%
def k(y):
    a=400000000
    b=350
    
    
    return  a-b*y
def dydt1(y, t):
    
    return k(y)*y
solve=odeint(dydt1,y0=740,t=years)
solve=solve.flatten()
plt.plot(years, solve, label = r"Мягкая модель Мальтуса")
plt.plot(years, people, label = r"Население Новосибирска", color="green")
plt.grid(True)
plt.legend()
plt.show()
